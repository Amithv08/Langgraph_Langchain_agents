# %%
import warnings
warnings.filterwarnings(
    "ignore",
    message="Langsmith now uses UUID 7",
    category=UserWarning
)

# %%
import os

from dotenv import load_dotenv

load_dotenv(override=True)

#automatically reloads all the modules before executing the new code.
# %load_ext autoreload
# %autoreload 2
